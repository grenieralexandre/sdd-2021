# %% [markdown]
# # Projet numérique de science des données - CAVÉ Claire et GRENIER Alexandre

# %% [markdown]
# ## Introduction au projet
#
# Il s'agit dans ce projet d'utiliser des données cartographiques décrivant des carrées de 30m x 30m pour construire un modèle prédictif de l'espèce d'arbre présente sur un tel carré.
#
# Le but final est d'appliquer ce modèle pour faire des prédictions pour des données pour lesquelles vous ne disposez pas d'une étiquette.
#
# __Consignes :__
# * Vous devez rendre, par binôme :
#     * un notebook jupyter
#     * un fichier de prédictions (voir plus bas pour le format)
# * __Renseignez vos noms/prénoms__ dans le titre du notebook
# * Vous avez jusqu'au __1er juillet midi heure de Paris__
# * Déposez vos fichiers [sur Campus](https://campus.mines-paristech.fr/course/view.php?id=404) dans la section dédiée (un seul rendu par binôme est nécessaire)
#
#
# __Déroulé :__
# * Les séances du lundi 14/06 (15h30-17h) et jeudi 24/06 (15h30-17h) sont dédiées au projet numérique. Faites-en bon usage.
# * Certaines sections font appel à des notions qui n'auront pas encore été vues le 14/06 ; c'est indiqué le cas échéant.

# %% [markdown]
# ## Données

# %% [markdown]
# ### Données publiques et privées
#
# Le dossier `data/` contient deux jeux de données :
# * `data/foret_public.tsv` contient les données étiquetées, à partir desquelles construire votre modèle
# * `data/foret_prive.tsv` contient les données non-étiquetées, pour lesquelles faire vos prédictions.
#
# Chaque ligne dans les données correspond à un carré de 30 m x 30m, décrit par les variables suivantes :
# * `altitude` : altitude en mètres
# * `exposition` : azimut en degrés
# * `pente` : pente en degrés
# * `distance_horizontale_hydro` : distance horizontale au point d'eau le plus proche (en mètres)
# * `distance_verticale_hydro` : distance verticale au point d'eau le plus proche (en mètres)
# * `distance_horizontale_route` : distance horizontale à la route la plus proche (en mètres)
# * `ombrage_0900` : index d'ombrages à 9h du matin, au solstice, sur une échelle de 0 à 255
# * `ombrage_1200` : index d'ombrages à midi, au solstice, sur une échelle de 0 à 255
# * `ombrage_1500` : index d'ombrages à 15h, au solstice, sur une échelle de 0 à 255
# * `distance_horizontale_depart_feu` : distance horizontale au départ de feu de forêt le plus proche (en mètres)
# * `espece` : étiquette : espèce d'arbre présente (0 = pin tordu ; 1 = peuplier)|

# %% [markdown]
# ### Chargement des données étiquetées

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
df_public = pd.read_csv('data/foret_public.tsv', delimiter='\t')

# %%
df_public.head()
# Out:
#    altitude  exposition  pente  distance_horizontale_hydro  \
# 0      2804         139      9                         268
# 1      2785         155     18                         242
# 2      2579         132      6                         300
# 3      2886         151     11                         371
# 4      2742         134     22                         150
#
#    distance_verticale_hydro  distance_horizontale_route  ombrage_0900  \
# 0                        65                        3180           234
# 1                       118                        3090           238
# 2                       -15                          67           230
# 3                        26                        5253           234
# 4                        69                        3215           248
#
#    ombrage_1200  ombrage_1500  distance_horizontale_depart_feu  espece
# 0           238           135                             6121       0
# ...

# %% [markdown]
# ### Extraction de la matrice de design et des étiquettes

# %%
X_public = np.array(df_public.drop(columns=["espece"]))
y_public = np.array(df_public["espece"])
print(np.shape(X_public))
# Out:
# (6000, 10)

# %% [markdown]
# ### Visualisation des variables
#
# #### Question 1
# Visualisez chacune des variables de `X_public` sous la forme de deux histogrammes superposés, l'un correspondant aux observations de la classe positive, l'autre correspondant aux observations de la classe négative.
#
# __Conseils :__
# * utilisez `pos_indices = np.where(y_public==1)[0]` pour déterminer les indices des lignes de `y_public` (et donc dans `X_public`) dont l'étiquette vaut 0.
# * utilisez l'argument `alpha` de `plt.hist` pour rendre vos histogrammes transparents.

# %%
pos_indices_0 = np.where(y_public==0)[0]
pos_indices_1 = np.where(y_public==1)[0]
print(pos_indices_0,pos_indices_1)
X_public_0=X_public[0:2999]
X_public_1=X_public[3000:5999]
fig=plt.figure(figsize=(18, 6))
for i in range(len(X_public[0])):
    a=fig.add_subplot(2,5,i+1)
    a.hist(X_public_0[:,i],alpha=1)
    a.hist(X_public_1[:,i],alpha=0.6)
    a.set_title(df_public.columns[i])
fig.tight_layout(pad=1.0)
plt.show()
# Out:
# [   0    1    2 ... 2997 2998 2999] [3000 3001 3002 ... 5997 5998 5999]

# %% [markdown]
# #### Question 2
# Pensez-vous qu'il va être aisé de distinguer les deux classes ?

# %% [markdown]
# #### Réponse 2
#
# Pour la plupart des variables, les histogrammes des deux classes se chevauchent et sont presques identiques. Il y a cependant certaines variables comme l'altitude ou la distance verticale hydro qui sont plus discriminante. Il faut peut être réduire le nombre de variables en se concentrant sur les plus discriminantes ou en utilisant les composantes principales.

# %% [markdown]
# ### Pré-traitement des variables

# %% [markdown]
# #### Question 3
# Transformez vos variables d'une manière qui vous parait judicieuse, en vous appuyant notamment sur la PC 3. Vous pouvez essayer différents pré-traitements, mais ce n'est pas nécessaire. Justifiez vos choix. Utilisez un array numpy `X_public_preprocessed` pour enregistrer le résultat.

# %% [markdown]
# #### Réponse 3
# On va simplement centrer et réduire les variables pour équilibrer leur poids respectif.
#
# On pourra essayer de les normaliser si le modèle est insatisfaisant.

# %%
from sklearn import preprocessing
std_scale = preprocessing.StandardScaler().fit(X_public)
X_public_preprocessed = std_scale.transform(X_public)

fig=plt.figure(figsize=(16, 16))
for i in range(len(X_public[0])):
    a=fig.add_subplot(5,4,2*i+1)
    a.hist(X_public[:,i],alpha=1,color='b')
    a.set_title(df_public.columns[i])
fig.tight_layout(pad=1.0)
for i in range(len(X_public[0])):
    a=fig.add_subplot(5,4,2*(i+1))
    a.hist(X_public_preprocessed[:,i],alpha=1,color='r')
    a.set_title(df_public.columns[i]+'_centre_reduit')
fig.tight_layout(pad=1.0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Premier modèle : 5-NN

# %% [markdown]
# ### Algorithme des k plus proches voisins

# %% [markdown]
# Nous n'avons pas encore vu d'algorithme permettant d'entraîner un modèle de classification. Nous allons donc commencer avec un modèle simple : celui des __k plus proches voisins__ (ou __kNN__, pour _k nearest neighbors_).
#
# Dans ce modèle, la valeur de la fonction de décision en x est la proportion d'individus d'étiquette positive parmi les k plus proches voisins de x au sein des points du jeu d'entraînement ; k est fixé.

# %% [markdown]
# Nous allons commencer par utiliser un algorithme des k plus proches voisins avec k fixé à k=5.

# %% [markdown]
# #### Question 4
#
# Entraînez un modèle sur les données `(X_public_preprocessed, y_public)` grâce à la classe `KNeighborsClassifier` du module `neighbors` de `sklearn`, utilisez l'algorithme des 5 plus proches voisins pour entrainer un modèle sur votre jeu d'entraînement.
#
# Documentation https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

# %%
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier

# %%
k_model=KNeighborsClassifier(n_neighbors=5)
k_model.fit(X_public_preprocessed,y_public)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %% [markdown]
# ### Performance
#
# Il existe de nombreuses métriques pour évaluer les performances d'un algorithme de classification. Nous allons ici utiliser le F-score, dont vous trouverez une description dans la documentation du module `metrics` de `sklearn` : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score et https://scikit-learn.org/stable/modules/model_evaluation.html#precision-recall-f-measure-metrics.
#
# #### Question 5
# Quel serait sur nos données le F-score d'un modèle naïf prédisant systématiquement la classe positive ?

# %% [markdown]
# #### Réponse 5
#
# Pour un modèle prédisant systèmatiquement une étiquette positive, le score de précision serait $F_{\beta} = 0$ tandis que le recall serait $F_1 = 1$. En effet il prédirait bien toutes les valeures posisitives mais se tromperait systèmatiquement sur les issues négatives.

# %% [markdown]
# #### Question 6
#
# Quelle est le F-score du modèle de 5 plus proches voisins que vous venez d'entraîner, sur les données `(X_public_preprocessed, y_public)` ?

# %%
from sklearn.metrics import f1_score
print('Le F-score est de : ' + str(int(f1_score(y_public, k_model.predict(X_public_preprocessed), average='weighted')*10000)/100)+'%')
# Out:
# Le F-score est de : 92.41%

# %% [markdown]
# #### Question 7
# * Que pensez-vous de cette performance ?
# * Est-ce une bonne idée d'évaluer le modèle sur le jeu d'entraînement ? (Réfléchissez en particulier au cas où k=1.)

# %% [markdown]
# #### Réponse 7
#
# - Le F-Score est plutôt correct, il est très au dessus de 0.5, le modèle n'agit donc pas au hasard. Il faudrait consulter le cahier des charges pour voir si 92% est suffisant, mais étant donné qu'il s'agit d'une simple cartographie, pas de detecter une tumeur, quelques faux positifs ou faux négatifs ne devraient pas poser trop de problèmes.
#
# - Cependant ce score ne signifie pas grand chose seul car il a été établi sur le jeu d'entrainement. Il nous faut un jeu de test pour savoir s'il y a eu sous ou sur apprentissage ou si le modèle est aussi performant sur des données nouvelles.

# %% [markdown]
# ## Création d'un jeu de test
#
# À partir de maintenant, nous allons séparer les données en un jeu d'entraînement, que nous utiliserons pour entraîner différents modèles, et un jeu de test, que nous utiliserons pour les comparer. (Cf CM 8).

# %%
from sklearn import model_selection

# %%
# Use 20% for testing
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_public, y_public, test_size=0.20,
                                                                    stratify=y_public,
                                                                    random_state=42) 
X_train.shape, X_test.shape
# Out:
# ((4800, 10), (1200, 10))

# %% [markdown]
# ### Performance sur le jeu de test d'un 5-NN entraîné sur le jeu d'entrainement

# %% [markdown]
# #### Question 8.a
#
# Entrainez de nouveau un modèle avec l'algorithme des 5 plus proches voisins, mais cette fois, utilisez uniquement le jeu d'entraînement. __Attention__ à bien « entraîner » votre pre-processing sur le jeu d'entraînement seulement ; considérez le jeu de test comme des données que vous ne voyez pas au moment de l'entraînement.

# %%
std_scale = preprocessing.StandardScaler().fit(X_train)
X_train_preprocessed = std_scale.transform(X_train)

k_model_train=KNeighborsClassifier(n_neighbors=5)
k_model_train.fit(X_train_preprocessed,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %% [markdown]
# #### Question 8.b
# Évaluez le F-score sur le jeu de test du modèle entraîné à la question précédente.

# %%
std_scale = preprocessing.StandardScaler().fit(X_test)
X_test_preprocessed = std_scale.transform(X_test)
print('Le F-score est de : ' + str(int(f1_score(y_test, k_model.predict(X_test_preprocessed), average='weighted')*10000)/100)+'%')
# Out:
# Le F-score est de : 92.04%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# #### Question 9
# Commentez le F-score obtenu ci-dessus.

# %% [markdown]
# Le F-score est légérement plus faible de 0.40% ce qui est tout à fait correct, le modèle apprend très bien. On peut cependant chercher à améliorer le score de manière générale pour de meilleures prédictions. Pour cela on peut par exemple changer le paramètre $k$ du nombre de plus proches voisins.

# %% [markdown]
# ## [À partir du CM 8 / de la PC 4] Sélection du nombre de plus proches voisins

# %% [markdown]
# #### Question 10.a
# Utilisez maintenant une validation croisée pour sélectionner la valeur optimale du nombre de voisins avec `GridSearchCV` (voir notamment PC4).
#
# Vous pouvez utiliser la grille de valeurs de k suivante, ou la modifier :

# %%
k_values = np.arange(3, 32, step=2)

# %% [markdown]
# #### Question 10.b
# Quel est le F-score correspondant au nombre de voisins optimal ?

# %% [markdown]
# #### Question 10.c
#
# Quel est le F-score, sur le jeu de test, d'un modèle obtenu en entraînant un algorithme des k plus proches voisins, avec le k que vous venez de déterminer, sur le jeu d'entraînement ? Commentez.

# %% [markdown]
# ## [À partir de la PC 5] Régression logistique

# %% [markdown]
# ### Régression logistique non-régularisée

# %% [markdown]
# #### Question 11.a
#
# Entraînez une régression logistique non-régularisée sur le jeu d'entraînement.
#
# __Conseils :__
# * Vous trouverez les outils nécessaires dans la classe `LogisticRegression` du module `linear_model` de `scikit-learn` ; il s'agit ainsi d'une variante de la PC5. Comme toujours, référez-vous à la [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html).
# * Pour ne pas avoir de régularisation, utilisez `penalty='none'`

# %% [markdown]
# #### Question 11.b
# Évaluez le F-score de cette régression logistique non-régularisée sur le jeu de test.

# %% [markdown]
# #### Question 12
# Vous attendez-vous à ce qu'utiliser une régularisation l2 améliore les performances du modèle ? Pourquoi ?

# %% [markdown]
# #### Question 13.a
# Déterminez par validation croisée une valeur optimale du coefficient de régularisation d'une régression logistique avec régularisation ridge.

# %% [markdown]
# #### Question 13.b
# Quel est le F-score, sur le jeu de test, d'une régression logistique avec régularisation ridge et ce coefficient de régularisation optimal, entraînée sur le jeu d'entraînement ?

# %% [markdown]
# #### Question 13.c
# Commentez ce résultat en regard de votre réponse à la question 12.

# %% [markdown]
# #### Question 14
#
# Entraînez une forêt aléatoire sur le jeu d'entraînement et évaluez son F-score sur le jeu de test.
#
# __Conseils :__
# * Vous trouverez les outils nécessaires dans la classe `RandomForestClassifier` du module `ensemble` de `scikit-learn`.
# * Choisissez le nombre d'arbres par validation croisée.

# %% [markdown]
# ## Modèle final

# %% [markdown]
# #### Question 15.a
# Visualisez les performances des différents modèles (et pré-traitements) que vous avez évalués sur le jeu de test.

# %% [markdown]
# #### Question 15.b
# Utilisez cette figure pour __sélectionner votre modèle favori__. Quel pré-traitement choisissez-vous ? Quel algorithme choisissez-vous, avec quel hyper-paramètre ?

# %% [markdown]
# #### Question 16.a
# Chargez les données privées de `data/foret_prive.tsv` pour obtenir un array `X_private`. Le fichier suit la même syntaxe que `data/foret_public.tsv`, mais sans la colonne des étiquettes.

# %% [markdown]
# #### Question 16.b
# Appliquez le pré-traitement que vous avez choisi à l'intégralité du jeu de données public `X_public` pour obtenir `X_public_preprocessed`.

# %% [markdown]
# #### Question 16.c
# Appliquez à `X_private` le pré-traitement que vous avez choisi ; enregistrez le résultat dans `X_private_preprocessed`.

# %% [markdown]
# #### Question 16.d
# Entraînez l'algorithme que vous avez sélectionné sur l'intégralité des données publiques `(X_public_processed, y_public)`.

# %% [markdown]
# #### Question 16.e
# Prédisez les étiquettes de `X_private_preprocessed` ; enregistrez le résultat dans un array `y_pred_final`

# %% [markdown]
# #### Question 16.f
# Utilisez le code suivant pour créer le fichier de prédictions que vous rendrez.
#
# __Attention__ Si vous ouvrez ce fichier avec un programme externe type Microsoft Excel ou LibreOffice Calc pour le lire, il est possible que ce programme modifie le fichier sans que vous ne le réalisiez. Préférez utiliser une commande bash type `less` ou `cat` ou éditeur de texte simple ; ou alors assurez-vous de relancer la commande.

# %%
# Save array to file
np.savetxt("test_file.tsv", 
           y_pred_final,
           fmt=('%d'), 
           header='Prediction',
           delimiter='\t', comments="")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6b1b5886e5df> in <module>()
#       1 # Save array to file
#       2 np.savetxt("test_file.tsv",
# ----> 3            y_pred_final,
#       4            fmt=('%d'),
#       5            header='Prediction',
#
# NameError: name 'y_pred_final' is not defined

# %% [markdown]
# ## Bonus

# %% [markdown]
# 1. En alternative au F-score, utilisez des courbes ROC (et l'aire sous ces courbes) pour comparer vos modèles. Attention à utiliser les méthodes `predict_proba()` plutôt que `predict()` pour obtenir des scores non-seuillés plutôt que des prédictions binaires. Documentation pertinente : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_roc_curve.html et  https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html.
#
# 1. Explorez d'autres pré-traitements (comme par exemple le fait de réduire la dimension des données) et d'autres algorithmes d'apprentissage implémentés dans scikit-learn (par exemple SVM, perceptrons multi-couches) pour essayer d'améliorer vos prédictions et reprenez la question 15.
